# %%
import sys
from pathlib import Path
import pandas as pd

# Path to your project root (which contains the `src` folder)
project_root = Path("/Users/yasaman/Desktop/dataminin-project/RAG_Embeddings/data")
sys.path.append(str(project_root))


csv_name = "qa_dataset_by_parts.csv"  
csv_path = project_root / csv_name

# Load the data
df = pd.read_csv(csv_path)

# Show basic info about structure
print("🔍 CSV Structure:")
print(df.info())  
print("\n📌 Sample rows:")
print(df.head(5))  

# Show unique values in each column (if categorical)
print("\n🧠 Unique values per column (up to 5 each):")
for col in df.columns:
    unique_vals = df[col].unique()
    print(f" - {col}: {unique_vals[:5]}{'...' if len(unique_vals) > 5 else ''}")
# Out:
# 🔍 CSV Structure:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   document        240 non-null    object
#  1   part            240 non-null    int64
#  2   question_type   240 non-null    object
#  3   question        240 non-null    object
#  4   answer          240 non-null    object
#  5   choices         120 non-null    object
#  6   correct_answer  240 non-null    object
#  7   chunk_excerpt   240 non-null    object
# dtypes: int64(1), object(7)
# memory usage: 15.1+ KB
# None
#
# 📌 Sample rows:
#                                             document  part    question_type  \
# 0  Norme_generali_del_comparto_turistico_Vademecu...     1            short
# 1  Norme_generali_del_comparto_turistico_Vademecu...     1  multiple_choice
# 2  Norme_generali_del_comparto_turistico_Vademecu...     2            short
# ...
